# %% [markdown]
# <hr>
# ### Problema 1:
#
# Considere un espacio del problema donde el estado inicial es el número 1 y cada estado $k$ tiene dos sucesores: $2k$ y $2k+1$
#
# Trabajen en lo siguiente:
#
# 1. Dibuje la porción del espacio del problema para los estados 1 al 15.
#
#  <img src="res/ejercicio1-3.jpg" width="600px">
#
# 2. FORMULE el problema para el estado inicial $I = 1$ y el objetivo $O = 13$.
#
# Respuesta:
#
# $2k+1$, $2k$
#
# 3. Liste el orden en que se visitan los nodos y utilizando las estrategias de búsqueda BFS, Depth-Limited Search con límite igual a 3 e IDS para el problema anteriormente formulado.
#
#
# 4. Nombremos la acción que va del estado $k$ al estado $2k$ como LEFT y la acción que va del estado $k$ al estado $2k+1$ RIGHT. Proponga un algoritmo que arroje la solución al problema para un objetivo $O$ arbitrario, sin utilizar una estrategia de búsqueda
#
#  <img src="res/ejercicio1-11.png" width="600px">
#
# Respuesta:
#
# Búsqueda por niveles en el árbol
# Se tomará el nodo raíz y se busca en cada uno de sus hijos (nivel 1), si lo encuentra detendrá la búsqueda, si no lo encuentra, toma esos hijos, los convierte en padres y se repite el ciclo hasta encontrar lo buscado.

# %% [markdown]
# <hr>
# ### Problema 2:
#
# <img src="res/problema2.png" width="600px">
#
# Considere el problema de encontrar una ruta entre dos puntos en un plano que tiene obstaculos poligonales CONVEXOS cómo se muestra en la figura 1. Trabaje en lo siguiente:
#
# 1. Suponga que el espacio de estados consiste en todas las posiciones $(x,y)$ en el plano. ¿Cuántos estados tendría ese espacio?
#
# Respuesta:
#
# El espacio tendría infinitos estados, ya que cada posición (x,y) es un estado y estas posiciones pueden ser infinitas.
#
# ¿Cuántas soluciones tendría el problema?
#
# Puede haber Infinitas soluciones.
#
# 2. Explique brevemente por qué la ruta más corta entre un vértice de un poligono a cualquier otro en la escena, debe consistir en una línea recta que une dichos vértices. A partir de lo anterior, ¿cuántos estados tendría el espacio del problema?
#
# Respuesta:
#
# Con la condición que los vértices de 2 polígonos sea una línea recta, podemos descartar que esos dos vértices haya polígono u obstáculo de por medio.
# Según lo mencionado anteriormente los estados del espacio son Estado inicial y estado final mas el numero de vértices de los polígonos dentro del espacio. En este caso el numero de estados es 35
#
#
#
# 3. Utilizando el razonamiento anterior, FORMULE el problema.
#
# Respuesta:
#
# Formulación del Problema:
#
# 	Estado Inicial: (Ix, ly)
#
# 	Estado Objetivo: (Ox, Oy)
#
# 	Función de Sucesión: Esta función recibirá un parámetro un punto (x, y) y a partir de este punto nos retornará un arreglo con los puntos (x, y) a los que este punto puede llegar mediante una línea recta sin obstáculo alguno
#
#
# 4. Aplique 1 o más algoritmos de búsqueda no-informada al problema formulado.

# %% [markdown]
# <hr>
# ### Problema 3:
#
# **Exploración de literatura y análisis**:
#
#
# Se desea realizar un programa al cual se le ingresen dos URLs y que encuentre una ruta de enlaces web que lleven de la una a la otra. Trabajar en lo siguiente:
#
#
# 1. FORMULE el problema anterior.
#
# Respuesta:
#
# 	Estado Inicial: Url1
#
# 	Estado Objetivo: Url2
#
# 	Función de Sucesión: A la función se le envía por parámetro un URL y esta nos retorna todas las posibles URLS a las que se relacione con el parámetro ingresado.
#
# 2. Cómo podría utilizar las estrategias de búsqueda no-informada para desarrollar el programa anterior? (ilustrar).
#
#
# 3. Es posible que la estrategia de búsqueda bidireccional (bidirectional search) se pueda utilizar para este propósito?.
#
# Respuesta:
#
# Se utiliza la estrategia de búsqueda BFS, en la URL1 como en la URL2 y se comparan los nodos hijos de la URL1 con todos los nodos de la URL2, hasta que se encuentre un nodo en común entre ambas URLS
#
# <img src="res/ejercicio3-1.jpg" width="600px">
#
# <img src="res/ejercicio3-2.jpg" width="400px">
#
#
# URL1: www.google.com
#
# URL2: www.youtube.com
#
# URL3: https://web.whatsapp.com
#
# URL4: https://www.instagram.com
#
# URL5: http://www.wechat.com
#
# URL6: http://www.imqq.com
#
# URL7: https://www.tumblr.com
#
# URL8: https://web.whatsapp.com
#
# URL9: https://www.linkedin.com/
#
# URL10: https://twitter.com
#
# URL11: https://www.weibo.com
#
# URL12: https://www.snapchat.com/l/es/
#
# URL13: https://tieba.baidu.com/
#
# URL14: https://www.skype.com/es/
#
# URL15: https://www.viber.com/es/
#
# URL16: https://www.reddit.com/
#
# URL17: https://line.me/es/
#
# URL18: https://soundcloud.com/
#
# URL19: https://badoo.com/
#
# URL20: https://vine.co/
#
# URL21: https://es.pinterest.com/
#
# URL22: https://plus.google.com/discover
#
# URL23: https://www.spotify.com/co/
#
# Luego de tener diseñado el árbol se puede observar que la URL 3 (Inicio) y 8 (Destino) tienen un nodo en común el cual se podría navegar por medio los enlaces.
#
# 4. A nivel técnico, ¿podría utilizar un motor de búsqueda como Google, Bing o DuckDuckGo para escribir la función de sucesión $S$? ¿Cómo lo haría?. Detalle lo que más pueda esta respuesta.
#
# Respuesta:
#
# Se puede implementar la estrategia Búsqueda bidireccional search para este propósito, debido a que el método tiene presente el punto inicial y el punto final, adicional realiza una búsqueda a lo ancho en los nodos hasta encontrar un nodo en común mediante la búsqueda. Al encontrar el nodo en común se encuentra la ruta entre las 2 URLS.

# %% [markdown]
# Integrantes:
#
# Mario Francisco Gutierrez Aleman
#
# John Fredy Zapata Zapata
